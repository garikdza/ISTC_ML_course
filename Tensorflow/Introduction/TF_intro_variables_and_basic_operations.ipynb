# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Tesnorflow have a tre types of variables

# %% [markdown]
# ### Constant

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = tf.constant(3.0, dtype=tf.float32)
b = tf.constant(4.0) # also tf.float32 implicitly
total = a + b
print(a)
print(b)
print(total)
# Out:
# Tensor("Const:0", shape=(), dtype=float32)
# Tensor("Const_1:0", shape=(), dtype=float32)
# Tensor("add:0", shape=(), dtype=float32)

# %% [markdown]
# ### Variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var1 = tf.Variable(3.0, dtype=tf.float32)
var2 = tf.Variable(4.0) # also tf.float32 implicitly
total2 = tf.add(var1,var2)
print(var1)
print(var2)
print(total2)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32_ref>
# <tf.Variable 'Variable_1:0' shape=() dtype=float32_ref>
# Tensor("Add_1:0", shape=(), dtype=float32)

# %% [markdown]
# ### Placeholders

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)
z = tf.add(x,y)
print(x)
print(y)
print(z)
# Out:
# Tensor("Placeholder:0", dtype=float32)
# Tensor("Placeholder_1:0", dtype=float32)
# Tensor("Add_2:0", dtype=float32)

# %% [markdown]
# #### Bee careful with types

# %%
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float64)

try:
    z = tf.add(x,y)
except:
    print("Input 'y' of 'Add' Op has type float64 that does not match type float32 of argument 'x'.")
# Out:
# Input 'y' of 'Add' Op has type float64 that does not match type float32 of argument 'x'.

# %% [markdown]
# ### What is TensorFlow's Eager API ?

# %% [markdown]
# Eager execution is an imperative, define-by-run interface where operations are executed immediately as they are called from Python. This makes it easier to get started with TensorFlow, and can make research and development more intuitive. A vast majority of the TensorFlow API remains the same whether eager execution is enabled or not. As a result, the exact same code that constructs TensorFlow graphs (e.g. using the layers API) can be executed imperatively by using eager execution. Conversely, most models written with Eager enabled can be converted to a graph that can be further optimized and/or extracted for deployment in production without changing code. - Rajat Monga
#
# More info: https://research.googleblog.com/2017/10/eager-execution-imperative-define-by.html

# %%
tf.reset_default_graph()

# %%
print("Setting Eager mode...")
tf.enable_eager_execution()
tfe = tf.contrib.eager
# Out:
# Setting Eager mode...
# WARNING: Logging before flag parsing goes to stderr.
# W0709 21:07:37.053235 140387265349440 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# Define constant tensors
print("Define constant tensors")
a = tf.constant(2)
print("a = %i" % a)
b = tf.constant(3)
print("b = %i" % b)
# Out:
# Define constant tensors
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab3d95219613> in <module>
#       1 # Define constant tensors
#       2 print("Define constant tensors")
# ----> 3 a = tf.constant(2)
#       4 print("a = ", a)
#       5 b = tf.constant(3)
#
# NameError: name 'tf' is not defined

# %%
# Run the operation without the need for tf.Session
print("Running operations, without tf.Session")
c = a + b
print("a + b = %i" % c)
d = a * b
print("a * b = %i" % d)
# Out:
# Running operations, without tf.Session
# a + b = 5
# a * b = 6

# %%
# Full compatibility with Numpy
print("Mixing operations with Tensors and Numpy Arrays")

# Define constant tensors
a = tf.constant([[2., 1.],
                 [1., 0.]], dtype=tf.float32)
print("Tensor:\n a = %s" % a)
b = np.array([[3., 0.],
              [5., 1.]], dtype=np.float32)
print("NumpyArray:\n b = %s" % b)
# Out:
# Mixing operations with Tensors and Numpy Arrays
# Tensor:
#  a = tf.Tensor(
# [[2. 1.]
#  [1. 0.]], shape=(2, 2), dtype=float32)
# NumpyArray:
#  b = [[3. 0.]
#  [5. 1.]]

# %%
# Run the operation without the need for tf.Session
print("Running operations, without tf.Session")

c = a + b
print("a + b = %s" % c)

d = tf.matmul(a, b)
print("a * b = %s" % d)
# Out:
# Running operations, without tf.Session
# a + b = tf.Tensor(
# [[5. 1.]
#  [6. 1.]], shape=(2, 2), dtype=float32)
# a * b = tf.Tensor(
# [[11.  1.]
#  [ 3.  0.]], shape=(2, 2), dtype=float32)
